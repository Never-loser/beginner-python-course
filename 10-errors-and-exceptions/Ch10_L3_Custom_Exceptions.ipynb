# %% [markdown]
# # Chapter 10 — Lesson 3
# # Creating Your Own Exceptions

# %% [markdown]
# ### 1. `raise` — Triggering an Error on Purpose

# %%
def set_age(age):
    if age < 0 or age > 120:
        raise ValueError("Age must be between 0 and 120.")
    return age

print(set_age(25))
# set_age(-5)   # uncomment to see the raised error

# %% [markdown]
# ### 2. Defining a Custom Exception Class
# You can create your own exception type by inheriting from `Exception`.

# %%
class InvalidAgeError(Exception):
    pass

def set_age(age):
    if age < 0 or age > 120:
        raise InvalidAgeError(f"{age} is not a valid age.")
    return age

set_age(-5)

# %% [markdown]
# ### Exercises
#
# **🟢 Easy**
# Write a function that validates **your own real age** is between 0 and 120, raising a plain `ValueError` with a custom message if not. Test it once with your real actual age (should succeed) and once with an obviously invalid joke value like `-5` (should raise).
#
# **🟡 Medium**
# Run the `InvalidAgeError` example above and screenshot the **full real traceback**, showing your custom class name appearing in the error output. In a markdown cell, explain in your own words what specifically changes in the traceback compared to a plain `ValueError`.
#
# **🔴 Hard**
# Design **your own real password rule** (e.g. "must be at least 8 characters and contain a number" — pick your own real specific rule). Create a custom exception class `WeakPasswordError`, and a function that checks a password string against your rule, raising your custom exception with a message naming exactly which part of your rule failed. Test it with **3 different example passwords** (use obviously fake example passwords, not a real one of yours) that each fail your rule in a **different way**, and one that passes. Screenshot all 4 runs.
# > Requires a genuinely self-designed validation rule (not the lesson's own example) plus 4 real runs whose specific failure messages must correctly correspond to your own specific rule logic.

# %%
# Easy exercise

# %%
# Medium exercise

# %%
# Hard exercise
