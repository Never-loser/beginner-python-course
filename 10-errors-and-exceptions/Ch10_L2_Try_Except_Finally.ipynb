# %% [markdown]
# # Chapter 10 — Lesson 2
# # `try`, `except`, and `finally`

# %% [markdown]
# ### 1. Catching an Error Instead of Crashing

# %%
try:
    age = int(input("Enter your age: "))
    print("Next year you will be", age + 1)
except ValueError:
    print("That was not a valid number.")

# %% [markdown]
# ### 2. `finally` — Always Runs
# Whether or not an error occurred, the `finally` block always executes.

# %%
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Cannot divide by zero.")
finally:
    print("This always runs.")

# %% [markdown]
# ### Exercises
#
# **🟢 Easy**
# Write code that asks for your **own real age** with `input()` inside a `try`/`except ValueError` block, so it doesn't crash if someone types letters instead. Run it **twice**: once typing your real actual age (valid), and once deliberately typing letters (invalid), and screenshot both real runs.
#
# **🟡 Medium**
# Take the `finally` example above. Run it as-is and screenshot the output order. Then, **predict first** (markdown cell) what happens if you change `except ZeroDivisionError` to `except ValueError` instead (a mismatched exception type) — will `finally` still run? Will the program still crash? Run it and screenshot the real result to check your prediction.
#
# **🔴 Hard**
# Build a small real two-number calculator: ask for two real numbers with `input()` and an operation (`+`, `-`, `*`, `/`), wrapped in `try`/`except` catching **both** `ValueError` (bad number input) and `ZeroDivisionError` (dividing by zero) with **different, specific messages** for each. Run it **3 separate times**: once with valid real numbers producing a correct result, once triggering the `ValueError` on purpose, and once triggering the `ZeroDivisionError` on purpose. Screenshot all three real interactive runs.
# > Requires 3 genuinely separate live interactive sessions on your machine with real typed input for each distinct failure mode — a single static screenshot cannot cover all three real branches.

# %%
# Easy exercise

# %%
# Medium exercise
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Cannot divide by zero.")
finally:
    print("This always runs.")

# %%
# Hard exercise
