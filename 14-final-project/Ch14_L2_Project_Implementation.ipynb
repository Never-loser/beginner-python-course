# %% [markdown]
# # Chapter 14 — Lesson 2
# # Step-by-Step Implementation
#
# Follow this scaffold **in order**, filling in each section with your own real project from Lesson 1. Do not skip ahead — each section builds on the last, and your instructor may ask you to run cells in this exact order live to prove you built it yourself.

# %% [markdown]
# ## Step 1 — Your Class Definition
# Define your main class (`Expense`, `Contact`, or `Goal`) with `__init__` and at least one method.

# %%
# Step 1: class definition

# %% [markdown]
# ## Step 2 — Your Data List
# Create the list that will hold your real instances.

# %%
# Step 2: the list

# %% [markdown]
# ## Step 3 — Your `add_item()` Function
# A function that creates a new instance from real input (or real hard-coded data) and adds it to the list.

# %%
# Step 3: add_item()

# %% [markdown]
# ## Step 4 — Your `show_all()` Function
# A function that prints every item in the list in a readable way.

# %%
# Step 4: show_all()

# %% [markdown]
# ## Step 5 — Add 3+ Real Items
# Call `add_item()` at least 3 times with your own real data, then call `show_all()`.

# %%
# Step 5: add real items and show them

# %% [markdown]
# ## Step 6 — Save to a File
# Write a `save_to_file()` function using `with open(...) as f:` that saves your real list to a text file.

# %%
# Step 6: save_to_file()

# %% [markdown]
# ## Step 7 — Load From a File
# Write a `load_from_file()` function that reads the file back and rebuilds your list, wrapped in `try`/`except` in case the file doesn't exist yet.

# %%
# Step 7: load_from_file()

# %% [markdown]
# ## Step 8 (Bonus) — Menu Loop
# If attempting the Bonus tier, build a `while` loop with `input()` offering real menu choices (add / show / save / quit).

# %%
# Step 8 (bonus): menu loop

# %% [markdown]
# ## Final Check
# Take a screenshot of your **full working run** — from an empty list, through adding your real items, to a successful save and reload — with the `In [ ]:` numbers visible proving you ran it step-by-step, in this order, yourself.
