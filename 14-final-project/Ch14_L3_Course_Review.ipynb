# %% [markdown]
# # Chapter 14 — Lesson 3
# # Course Review and Wrap-Up
#
# ## Everything You've Learned
# | Chapter | Topic |
# |---|---|
# | 1 | Setup — VS Code, Jupyter |
# | 2 | Variables, data types, casting, `input()` |
# | 3 | Arithmetic, comparison, logical, assignment operators |
# | 4 | Strings, indexing, slicing, methods, f-strings |
# | 5 | `if` / `elif` / `else` |
# | 6 | Lists and tuples |
# | 7 | Sets and dictionaries |
# | 8 | `for`, `while`, `break`/`continue`, list comprehension |
# | 9 | Functions, parameters, `*args`/`**kwargs`, lambda |
# | 10 | Error handling, custom exceptions |
# | 11 | Reading/writing files, `with open()` |
# | 12 | Classes, objects, `__init__`, methods |
# | 13 | Your final project |

# %% [markdown]
# ## Final Reflection
# In a markdown cell, answer honestly and specifically about **your own real experience** in this course (not generic statements):
#
# 1. Which single topic was genuinely the **hardest** for you, and what specifically made it hard?
# 2. Which exercise are you **most proud of**, and why?
# 3. Name **one real, specific thing** (an app, a website, a task at your real job or school) where you can now imagine actually using Python.
# 4. What's the next thing you personally want to learn or build?

# %%
# Optional: if you'd like, write a short closing note to your future self as a code comment here.
