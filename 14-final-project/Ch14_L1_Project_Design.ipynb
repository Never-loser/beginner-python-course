# %% [markdown]
# # Chapter 14 — Lesson 1
# # Designing Your Final Project
#
# ## Your Mission
# Build a small, **real, personally useful** command-line application that combines everything from this course: variables, conditionals, loops, functions, a list/dict, file saving/loading, at least one custom class, and error handling.
#
# **Important rule: use your own real, ongoing data — not invented sample data.** The whole point of this project is that it should be something *you* would actually want to keep using.
#
# ## Pick ONE Real Theme
# - **Personal Expense Tracker** — log real things you spend money on, save/load from a file, show real totals and categories.
# - **Personal Contact Book** — store real contacts (real first names + real info you're comfortable sharing, like favorite color or birthday month), save/load from a file, search/update/delete.
# - **Personal Study/Goal Tracker** — log real goals you're working on, their real status and deadlines, save/load from a file, mark progress.
#
# ## Requirement Tiers
#
# **🟢 Core (must have)**
# - At least one custom **class** representing your main "thing" (an Expense, a Contact, a Goal...).
# - A **list** holding multiple real instances of that class.
# - At least 2 **functions** (e.g. `add_item()`, `show_all()`).
# - Saving your real data to a file and loading it back with `with open()`.
# - At least one `try`/`except` protecting against a real possible user mistake.
#
# **🟡 Bonus**
# - A simple **text menu loop** (`while` loop + `input()`) letting the user choose actions repeatedly until they choose "quit".
# - Sorting your real data (e.g. expenses by price, contacts alphabetically) using `sorted()` with a `lambda` key.
# - A method on your class that computes something derived (e.g. `Expense.is_expensive()`, `Goal.days_remaining()`).
#
# **🔴 Stretch**
# - A **custom exception class** for one specific real validation rule you define yourself.
# - A summary report function using an **f-string table** (aligned columns, like Chapter 4 Lesson 4's receipt exercise).
# - Handling the case where the save file doesn't exist yet (first run) gracefully.
#
# ## Planning Cell
# Before writing any code, answer these in a markdown cell **in your own words, about your own real chosen theme**:
# 1. Which theme did you pick, and why is it genuinely useful to you (not just "because it's easiest")?
# 2. What attributes will your main class have?
# 3. What are the 2+ functions you'll need, and what will each do?
# 4. What does one real line of your data file look like (write an actual example line)?

# %%
# Planning notes as code comments are fine too, but the markdown cell above is the real deliverable for this lesson.
